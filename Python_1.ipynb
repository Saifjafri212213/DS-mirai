# %% [markdown]
# <a href="https://colab.research.google.com/github/Saifjafri212213/DS-mirai/blob/Saif-Jafri/Python_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("helloworld")
# Out:
# helloworld

# %%
a = input("enter your name")
print("Your name is" , a)
# Out:
# enter your nameSaif
# Your name is Saif

# %%
a = input()
b = input()
print(a+b)
# Out:
# 4
# 4
# 44

# %%
a = int(input())
b = int(input())
c = int(input())
d = int(input())
e = int(input())
print(a+b+c+d+e)
# Out:
# 3
# 4
# 6
# 2
# 1
# 16

# %%
a = 10
b = 20
print("a is " , a)
print("b is " , b)

c=a
print("c is " , c)

a = a^b
b = a^b
a = a^b
print(a,b)
# Out:
# a is  10
# b is  20
# c is  10
# 20 10

# %%
a = input()
if a=="sun":
  print("Sunday")
elif a=="mon":
  print("Monday")
elif a=="tue":
  print("Tuesday")
elif a=="wed":
  print("Wednesday")
elif a=="thu":
  print("Thursday")
elif a=="fri":
  print("Friday")
else :
  print("Saturday")
# Out:
# mon
# Monday

# %%
a = int(input())
e = []
o = []
for i in range(a+1):
  if i%2==0:
    e.append(i)
  else:
    o.append(i)

  print(e)
  print("this",o)
# Out:
# 10
# [0]
# this []
# [0]
# this [1]
# [0, 2]
# this [1]
# [0, 2]
# this [1, 3]
# [0, 2, 4]
# this [1, 3]
# [0, 2, 4]
# this [1, 3, 5]
# [0, 2, 4, 6]
# this [1, 3, 5]
# [0, 2, 4, 6]
# this [1, 3, 5, 7]
# [0, 2, 4, 6, 8]
# this [1, 3, 5, 7]
# [0, 2, 4, 6, 8]
# this [1, 3, 5, 7, 9]
# [0, 2, 4, 6, 8, 10]
# this [1, 3, 5, 7, 9]

# %%
str = input()
if str==str[::-1]:
  print("True")
else:
  print("false")
# Out:
# saif
# false
